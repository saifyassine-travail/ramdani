# %% [markdown]
# # TASK_RSNA_PNEUMONIA — ResNet18 chest X-ray pneumonia classifier
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/REPLACE_WITH_GITHUB_USER/REPLACE_WITH_REPO/blob/main/radiology-lab/notebooks/04_rsna_pneumonia.ipynb)
#
# > **Status:** training implemented in Phase 2. Run `01_totalseg_infer` first.
#
# ImageNet-pretrained ResNet18, backbone frozen except `layer4` + new head. CPU: ~20-30 min for 2000 images / 5 epochs.

# %%
import sys
if 'google.colab' in sys.modules:
    # !pip -q install torch torchvision pydicom scikit-learn matplotlib pyyaml tqdm
import subprocess, sys
subprocess.run([sys.executable, '-m', 'train.train_rsna', '--config', 'configs/rsna_pneumonia.yaml', '--subset', '500'])
