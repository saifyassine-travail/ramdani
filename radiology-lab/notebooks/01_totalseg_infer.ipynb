# %% [markdown]
# # TASK_TOTALSEG_INFER — pretrained TotalSegmentator on a CT volume
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/REPLACE_WITH_GITHUB_USER/REPLACE_WITH_REPO/blob/main/radiology-lab/notebooks/01_totalseg_infer.ipynb)
#
# Runs the official pretrained model — **no training**. On Colab's free CPU/GPU this is dramatically faster than a laptop CPU.
#
# **To enable the badge:** push this repo to GitHub, then edit the URL above to your `user/repo`.

# %% [markdown]
# ## 1. Setup (Colab only — skip locally, use `make setup`)

# %%
import sys, os
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    # !pip -q install totalsegmentator==2.4.0 nibabel matplotlib pyyaml
    # Upload or mount a CT volume, then set the path below.
    from google.colab import drive; drive.mount('/content/drive')
print('Colab:', IN_COLAB)

# %% [markdown]
# ## 2. Run inference
# Locally, prefer `make totalseg-infer`. The cell below calls the same module.

# %%
# Run from the radiology-lab/ project root.
import subprocess, sys
subprocess.run([sys.executable, '-m', 'infer.totalseg_infer',
                '--config', 'configs/totalseg_infer.yaml'], check=True)

# %% [markdown]
# ## 3. Show the axial overlay

# %%
import json
from PIL import Image
import matplotlib.pyplot as plt
summary = json.load(open('outputs/totalseg_infer/metrics.json'))
print(summary['num_organs'], 'organs segmented')
plt.figure(figsize=(7,7)); plt.imshow(Image.open(summary['overlay_png'])); plt.axis('off'); plt.show()
