# %% [markdown]
# # TASK_LIDC_NODULE_CLS — nodule vs non-nodule CNN (LIDC-IDRI)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/REPLACE_WITH_GITHUB_USER/REPLACE_WITH_REPO/blob/main/radiology-lab/notebooks/03_lidc_nodule_cls.ipynb)
#
# > **Status:** training implemented in Phase 2. Run `01_totalseg_infer` first.
#
# `pylidc` needs a `~/.pylidcrc` pointing at the LIDC-IDRI DICOM root; the loader writes it for you from `configs/paths.yaml`.

# %%
import sys
if 'google.colab' in sys.modules:
    # !pip -q install pylidc pydicom scikit-learn matplotlib pyyaml tqdm
import subprocess, sys
subprocess.run([sys.executable, '-m', 'train.train_lidc', '--config', 'configs/lidc_nodule_cls.yaml', '--subset', '20'])
