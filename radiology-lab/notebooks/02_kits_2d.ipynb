# %% [markdown]
# # TASK_KITS_2D — 2D U-Net on KiTS23 kidney slices
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/REPLACE_WITH_GITHUB_USER/REPLACE_WITH_REPO/blob/main/radiology-lab/notebooks/02_kits_2d.ipynb)
#
# > **Status:** training implemented in Phase 2. Run `01_totalseg_infer` first to verify the environment.
#
# On Colab (free GPU) this trains in a few minutes; on a 4-core CPU expect ~30 min.

# %%
import sys
if 'google.colab' in sys.modules:
    # !pip -q install monai==1.3.2 nibabel scikit-learn matplotlib pyyaml tqdm
# From the radiology-lab/ project root:
import subprocess, sys
subprocess.run([sys.executable, '-m', 'train.train_kits', '--config', 'configs/kits_2d.yaml', '--subset', '4'])
